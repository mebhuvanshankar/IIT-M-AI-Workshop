# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]

# %%
plt.subplot(2,1,1)
plt.plot(x,y1)
plt.title('subplot')
plt.ylabel('y1 axis')
# Out:
# Text(0, 0.5, 'y1 axis')

# %%
plt.subplot(2,1,2)
plt.plot(x,y2)
plt.title('subplot')
plt.ylabel('y2 axis')
# Out:
# Text(0, 0.5, 'y2 axis')

# %%
plt.subplot(2,2,3)
plt.plot(x,y3)
plt.title('subplot')
plt.ylabel('y3 axis')
# Out:
# Text(0, 0.5, 'y3 axis')

# %%
plt.subplot(2,2,4)
plt.plot(x,y4)
plt.title('subplot')
plt.ylabel('y4 axis')
# Out:
# Text(0, 0.5, 'y4 axis')
